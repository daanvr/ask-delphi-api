# %% [markdown]
# # Notebook voor verschillende handelingen op topics in askdelphi
# Voordat we kunnen starten moeten we eerst zorgen dat de authenticatie op orde is. Hiervoor hebben we een ASKDELPHI_PORTAL_CODE nodig.

# %%
import os
import dotenv

dotenv.load_dotenv()

os.getenv("ASKDELPHI_PORTAL_CODE")
# Out:
# '5TB6HK-B2X839'

# %%
from askdelphi_client import AskDelphiClient

client = AskDelphiClient()

client.authenticate()
# Out:
# 2026-01-28 16:48:47 | INFO     | Initializing AskDelphiClient...
# 2026-01-28 16:48:47 | INFO     |   Parsed IDs from CMS URL
# 2026-01-28 16:48:47 | INFO     |   Tenant ID: 0be6d42b-c278-44e6-888e-ba122840d690
# 2026-01-28 16:48:47 | INFO     |   Project ID: 397296f6-20dd-45cd-8459-250db2725140
# 2026-01-28 16:48:47 | INFO     |   ACL Entry ID: 4ecd88f2-979b-4fb0-a95d-175d499bc375
# 2026-01-28 16:48:47 | INFO     |   Portal Code: 5TB6...X839
# 2026-01-28 16:48:47 | INFO     |   Portal Server: https://portal.askdelphi.com
# 2026-01-28 16:48:47 | INFO     |   API Server: https://edit.api.askdelphi.com
# 2026-01-28 16:48:47 | INFO     | Loaded cached tokens from .askdelphi_tokens.json
# 2026-01-28 16:48:47 | DEBUG    |   Publication URL: https://digitalecoach.askdelphi.com
# 2026-01-28 16:48:47 | INFO     | ============================================================
# 2026-01-28 16:48:47 | INFO     | AUTHENTICATION STARTED
# 2026-01-28 16:48:47 | INFO     | ============================================================
# 2026-01-28 16:48:47 | INFO     | Found cached tokens, trying to use them...
# 2026-01-28 16:48:47 | DEBUG    | Getting API token...
# 2026-01-28 16:48:47 | DEBUG    | API token expired or expiring soon, trying refresh...
# 2026-01-28 16:48:47 | DEBUG    | Refreshing tokens...
# 2026-01-28 16:48:47 | DEBUG    | ============================================================
# 2026-01-28 16:48:47 | DEBUG    | REQUEST: GET https://digitalecoach.askdelphi.com/api/token/refresh?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....K3gOJPWtGWmqwK1xHStyDOJmC1MqFUStDoW_U_y6to0&refreshToken=RigVBpz6HgabvNRAE8S0mcbyszpyqtwkeejBwCC/1pY=
# 2026-01-28 16:48:47 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 16:48:48 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 16:48:48 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 15:48:48 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '1063', 'Connection': 'keep-alive', 'Access-Control-Expose-Headers': 'Request-Context', 'Cache-Control': 'private', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=99762e18ad891432b0e579f71a2040bd889a4bf21332d81e853060cf05a42d65;Path=/;HttpOnly;Secure;Domain=digitalecoach.askdelphi.com, ARRAffinitySameSite=99762e18ad891432b0e579f71a2040bd889a4bf21332d81e853060cf05a42d65;Path=/;HttpOnly;SameSite=None;Secure;Domain=digitalecoach.askdelphi.com', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000', 'X-UA-Compatible': 'IE=edge', 'Request-Context': 'appId=cid-v1:6afe03cc-6beb-4194-a480-9f9e73f13632', 'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'no-referrer-when-downgrade', 'Permissions-Policy': 'accelerometer=(self), camera=(self), geolocation=(self), gyroscope=(self), magnetometer=(self), microphone=(self), payment=(self), usb=(self)', 'X-Permitted-Cross-Domain-Policies': 'none', 'Expect-CT': 'max-age=86400, enforce', 'x-azure-ref': '20260128T154848Z-r1f47c87566274pvhC1PAR8b6w0000000u6g000000001p0x', 'X-Cache': 'CONFIG_NOCACHE', 'Accept-Ranges': 'bytes'}
# 2026-01-28 16:48:48 | DEBUG    | Body (JSON): {
#   "refresh": "RigVBpz6HgabvNRAE8S0mcbyszpyqtwkeejBwCC/1pY=",
#   "token": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....QSoy0uH3lrW6s0rueEn9t4vFwHZBxkmPBlzqh1agoCk"
# }
# 2026-01-28 16:48:48 | DEBUG    | ============================================================
# 2026-01-28 16:48:48 | DEBUG    | Tokens saved to .askdelphi_tokens.json
# 2026-01-28 16:48:48 | INFO     | Tokens refreshed successfully
# 2026-01-28 16:48:48 | DEBUG    | ============================================================
# 2026-01-28 16:48:48 | DEBUG    | REQUEST: GET https://digitalecoach.askdelphi.com/api/token/EditingApiToken
# 2026-01-28 16:48:48 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 16:48:49 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 16:48:49 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 15:48:49 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '1238', 'Connection': 'keep-alive', 'Access-Control-Expose-Headers': 'Request-Context', 'Cache-Control': 'private, s-maxage=0', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=99762e18ad891432b0e579f71a2040bd889a4bf21332d81e853060cf05a42d65;Path=/;HttpOnly;Secure;Domain=digitalecoach.askdelphi.com, ARRAffinitySameSite=99762e18ad891432b0e579f71a2040bd889a4bf21332d81e853060cf05a42d65;Path=/;HttpOnly;SameSite=None;Secure;Domain=digitalecoach.askdelphi.com', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000', 'X-UA-Compatible': 'IE=edge', 'Request-Context': 'appId=cid-v1:6afe03cc-6beb-4194-a480-9f9e73f13632', 'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'no-referrer-when-downgrade', 'Permissions-Policy': 'accelerometer=(self), camera=(self), geolocation=(self), gyroscope=(self), magnetometer=(self), microphone=(self), payment=(self), usb=(self)', 'X-Permitted-Cross-Domain-Policies': 'none', 'Expect-CT': 'max-age=86400, enforce', 'x-azure-ref': '20260128T154849Z-r198d8c9676qx2hbhC1PARu2ec0000000m90000000001g4z', 'X-Cache': 'CONFIG_NOCACHE', 'Accept-Ranges': 'bytes'}
# 2026-01-28 16:48:49 | DEBUG    | Body (JSON): "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....f4wcya11IqwlxbT7Dw0s_xuhFo7Cx8U4GJN3vagHdIo"
# 2026-01-28 16:48:49 | DEBUG    | ============================================================
# 2026-01-28 16:48:49 | INFO     |   Received editing API token: eyJhbGciOiJIUzI1NiIsInR5cCI6Ik...
# 2026-01-28 16:48:49 | DEBUG    |   Token expires at: 2026-01-28 17:48:49
# 2026-01-28 16:48:49 | INFO     | SUCCESS: Authenticated using cached tokens
# True

# %% [markdown]
# Voor het verwijderen van een topic hebben we het topicVersionId nodig, deze krijgen we door onderstaande code te runnen.

# %%
topicId = "0ae17002-f49e-4ec3-a42a-94441509411f"
endpoint = f"/v1/tenant/{{tenantId}}/project/{{projectId}}/acl/{{aclEntryId}}/topic/{topicId}/workflowstate"

result = client._request("POST", endpoint,
                json_data={
                    "action": 1
                })

topicVersionId = result["topicVersionId"]

# %% [markdown]
# Vervolgens kunnen we de volgende code runnen, om het topic daadwerkelijk te verwijderen.

# %%
endpoint = f"v3/tenant/{{tenantId}}/project/{{projectId}}/acl/{{aclEntryId}}/topic/{topicId}/topicVersion/{topicVersionId}"

client._request("DELETE", endpoint,
                json_data={
                    "workflowActions": {}
                })

# %% [markdown]
# # Toevoegen van topic
# Hieronder staat hoe je een topic moet toevoegen

# %%
endpoint = "v4/tenant/{tenantId}/project/{projectId}/acl/{aclEntryId}/topic"
data = {
        "topicTitle": "Dit is een nieuwe digitale coach",
        "topicTypeId": "7d332fbb-44f5-469f-b570-874e701e526b"   # ID voor Digitale Coach Procespagina
}
client._request("POST", endpoint, json_data=data)
# Out:
# 2026-01-28 16:51:43 | DEBUG    | Getting API token...
# 2026-01-28 16:51:43 | DEBUG    | Using cached API token (still valid)
# 2026-01-28 16:51:43 | DEBUG    | ============================================================
# 2026-01-28 16:51:43 | DEBUG    | REQUEST: POST https://edit.api.askdelphi.com/v4/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic
# 2026-01-28 16:51:43 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 16:51:43 | DEBUG    | Body: {
#   "topicTitle": "Dit is een nieuwe digitale coach",
#   "topicTypeId": "7d332fbb-44f5-469f-b570-874e701e526b"
# }
# 2026-01-28 16:51:44 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 16:51:44 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 15:51:44 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net, ARRAffinitySameSite=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;SameSite=None;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net', 'Vary': 'Accept-Encoding', 'Request-Context': 'appId=cid-v1:2382112b-f772-4837-9e13-979f2d67c6fc', 'X-Powered-By': 'ASP.NET', 'x-azure-ref': '20260128T155143Z-r198d8c9676s7g42hC1PARu0r80000000hz00000000019wf', 'X-Cache': 'CONFIG_NOCACHE'}
# 2026-01-28 16:51:44 | DEBUG    | Body (JSON): {
#   "success": true,
#   "errorCode": null,
#   "errorMessage": null,
#   "response": {
#     "topicId": "72296fd3-db9a-45ef-89e7-26ebdaf1e661",
#     "topicVersionKey": "5aaadadf-e5d4-4196-956e-c26cd95f3012"
#   }
# }
# 2026-01-28 16:51:44 | DEBUG    | ============================================================
# {'topicId': '72296fd3-db9a-45ef-89e7-26ebdaf1e661',
#  'topicVersionKey': '5aaadadf-e5d4-4196-956e-c26cd95f3012'}

# %% [markdown]
# ## Eigenschappen wijzigen van een bestaand topic
# TO DO: daadwerkelijk wijzigen, nu alleen nog inhoud bekijken...
# Eerst gaan we kijken welke parts er allemaal in de topic zitten.

# %%
endpoint = f"v3/tenant/{{tenantId}}/project/{{projectId}}/acl/{{aclEntryId}}/topic/{topicId}/topicVersion/{topicVersionId}/part"

client._request("GET", endpoint,
                json_data={
                    "workflowActions": {}
                })

# %% [markdown]
# # ----------------------------------------------------------------------------------------------------------------------------
# ## Versiegeschiedenis van een topic
# Onderstaande code run je om de laatste versiegeschiedenis van een topic te krijgen. Leuk, maar lijkt even niet nodig te zijn voor het verwijderen van een topic!!

# %%
#topicId = "69cd3efd-d737-44a6-9401-ce26fb5d34ce"
endpoint = f"/v1/tenant/{{tenantId}}/project/{{projectId}}/acl/{{aclEntryId}}/topic/{topicId}/version/history/list"

test = client._request("GET", endpoint)

# %%
latest = test["data"][0]
topicVersionGuid = latest['topicVersionGuid']
print(topicVersionGuid)
