# %% [markdown]
# # API verbinding opzetten

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent          # ../ vanaf Notebooks/
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from pathlib import Path

# Vind de projectroot vanuit Notebooks/
project_root = Path.cwd().parent
src_path = project_root / "src"

# Voeg src/ toe aan modulezoekpad
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

print("Project root:", project_root)
print("SRC path:", src_path)
print("SRC path is in sys.path?", str(src_path) in sys.path)
# Out:
# Project root: c:\Users\veldi01\Documents\git\ask-delphi-api
# SRC path: c:\Users\veldi01\Documents\git\ask-delphi-api\src
# SRC path is in sys.path? True

# %%
import askdelphi
import inspect

print("askdelphi module file:", askdelphi.__file__)
print("askdelphi package content:", dir(askdelphi))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import askdelphi
#       2 import inspect
#       4 print("askdelphi module file:", askdelphi.__file__)
#
# File c:\Users\veldi01\Documents\git\ask-delphi-api\src\askdelphi\__init__.py:2
# ----> 2 from .authentication import AskDelphiClient
#       4 __all__ = [
#       5     "AskDelphiClient"
#       6 ]
#
# ImportError: cannot import name 'AskDelphiClient' from 'askdelphi.authentication' (c:\Users\veldi01\Documents\git\ask-delphi-api\src\askdelphi\authentication.py)

# %%
from askdelphi.authentication import AskDelphiClient
client = AskDelphiClient()
client.authenticate()   # pakt automatisch portal code uit .env
client.test_call()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from askdelphi.authentication import AskDelphiClient
#       2 client = AskDelphiClient()
#       3 client.authenticate()   # pakt automatisch portal code uit .env
#
# ImportError: cannot import name 'AskDelphiClient' from 'askdelphi.authentication' (c:\Users\veldi01\Documents\git\ask-delphi-api\src\askdelphi\authentication.py)
