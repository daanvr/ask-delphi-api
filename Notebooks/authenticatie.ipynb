# %% [markdown]
# # API verbinding opzetten
# In deze notebook zetten we een directe verbinding met AskDelphi via de API op.
# We gebruiken hiervoor een vereenvoudigde Python‑client die:
# - de portal‑code automatisch uit .env leest,
# - een beveiligde authenticatie uitvoert,
# - en een geldig Editing API Token ophaalt waarmee we verder kunnen werken.
#
# We beginnen met het inladen van de benodigde Python‑libraries, daarna definiëren we de SimpleAskDelphiClient, en tot slot voeren we de eerste authenticatie uit.

# %%
import sys
from pathlib import Path

# project_root = Path.cwd().parent          # ../ vanaf Notebooks/
# if str(project_root) not in sys.path:
#     sys.path.insert(0, str(project_root))

from askdelphi_client import AskDelphiClient
client = AskDelphiClient()
client.authenticate()   # pakt automatisch portal code uit .env
client.test_call()
# Out:
# Loaded cached tokens.
# ...
# AUTHENTICATION STARTED
# ...
# Trying cached tokens...
# Editing API token status: 200
# Editing API token acquired.
# SUCCESS using cached tokens!
# JWT begins with: eyJhbGciOiJIUzI1NiIs ...
# Ready for API operations!
