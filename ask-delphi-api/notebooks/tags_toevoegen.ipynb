# %% [markdown]
# # Tag(s) toevoegen
# Dit notebook ondersteunt het verkennen, analyseren van tag functionaliteit binnen AskDelphi.

# %% [markdown]
# ### Connectie met AskDelphi opzetten

# %%
import pprint
from ask_delphi_api.topictools import TopicTools
from ask_delphi_api.import_digicoach import Import

import_service = Import()
topic_tools = TopicTools(import_service.client, import_service.project)
# Out:
# AskDelphi Client loaded.
# Parsed tenant/project/acl from CMS URL
# Loaded cached tokens.
# ============================================================
# AUTHENTICATION STARTED
# ============================================================
# Trying cached tokens...
# Editing API token status: 200
# Editing API token acquired.
# SUCCESS using cached tokens!

# %% [markdown]
# ### Taaksjabloon uitlezen

# %%
from ask_delphi_api.convert_taaksjabloon import read_dir, convert_doc_to_json
import pprint

paths = read_dir('/Users/baasa03/Digicoach/taaksjabloon_demo')
json_coaches = []

for path in paths:
    try:
        print("\n\n")
        json_coach = convert_doc_to_json(path)
        json_coaches.append(json_coach)
    except ValueError as e:
        print(e)
# Out:
# LIC - Taaksjablonen Sanering v1.0.docx
#
#
#
# retrieved 9 tables from doc /Users/baasa03/Digicoach/taaksjabloon_demo/LIC - Taaksjablonen Sanering v1.0.docx
# Found title: Sanering (LIC)
# Found tag: Directie CAP
# Found tag: Keten Inning en betalingsverkeer
# Found step: Open postbak in WAB
# Found step: Selecteer alleen kwijtscheldings / saneringsverzoeken
# Found step: In behandeling nemen poststuk saneringen
# Found step: Controleer taken op je naam
# Found task: Selecteer Zaak
# Found step: Check op vermogensbestanddelen
# Found step: Check op mogelijkheid aansprakelijk stellen
# Found step: Check op teruggaven en goeder trouw
# Found step: Check op ambtshalve aanslagen
# Found step: Vastleggen acties
# Found task: Quick scan verzoek
# Found step: Controleer competentie
# Found step: Controleer de datum van binnenkomst
# Found step: Check op benodigde stukken
# Found step: Check op onbehandelde zaken
# Found step: Controleer volledigheid verzoek
# Found step: Vastleggen brief of actie in INL
# Found step: Acties bij verzoek is volledig
# Found step: Rappel sturen bij opgevraagde stukken en/of formulier niet ontvangen
# Found step: Verzoek afwijzen indien stukken niet ontvangen
# Found task: verzoek bekijken
# Found step: Beoordeel op (rechts)persoon
# Found step: Toets criteria Faillissementswet art. 287a
# Found step: Toets aan criteria art 19a Uitvoeringsregeling
# Found step: Verzamel informatie door invullen checklist
# Found step: Beoordeel informatie uit de ingestuurde stukken
# Found step: Wijs sanering toe
# Found step: Wijs sanering af
# Found task: Verzoek beoordelen
# Found step: Opstellen concept beschikking
# Found step: Goedkeuring vragen
# Found step: Definitieve beschikking sturen bij afwijzen
# Found step: Beschikking sturen bij toewijzen (evt. met voorwaarden
# Found task: Beschikking Uitbrengen
# Found sources: [{'titel': 'Kwijtscheldingsformulier Ondernemers', 'type': 'Bronnen', 'link': 'https://www.belastingdienst.nl/wps/wcm/connect/bldcontentnl/themaoverstijgend/programmas_en_formulieren/kwijtschelding_van_belasting_enof_premie_voor_ondernemingen'}, {'titel': 'Applicatie overzicht', 'type': 'Applicaties', 'link': 'https://connectpeople.belastingdienst.nl/files/form/anonymous/api/library/1fa8a980-ab6d-4c9a-a059-da1fea2c3dbf/document/1a372d7d-d07f-448a-8f2b-efa5c9690ec8/media/6980%20LIC%20-%20applicatie%20overzicht.pdf'}, {'titel': 'GDC - Standaardzinnen voor de sanering', 'type': 'Handleidingen en instructies', 'link': 'Word document (zelfde link als in de DC Sanering (Taskforce)'}, {'titel': 'LIC - memo - tijdelijke instructie coronasaneringen', 'type': 'Handleidingen en instructies', 'link': 'Word document (zelfde link als in de DC Sanering (Taskforce)'}, {'titel': 'LIC - checklist - bij tijdelijke instructie saneringen ondernemers', 'type': 'Handleidingen en instructies', 'link': 'Word document (zelfde link als in de DC Sanering (Taskforce)'}, {'titel': 'inl opvoeren aktie BRCAF in stamvervolging', 'type': 'Handleidingen en instructies', 'link': 'https://connectpeople.belastingdienst.nl/files/form/anonymous/api/library/1fa8a980-ab6d-4c9a-a059-da1fea2c3dbf/document/d704e5b5-fc97-42de-95f0-b234e5ca2f4a/media/4396%20LIC%20-%20inl%20opvoeren%20aktie%20BRCAF%20in%20stamvervolging.pdf'}, {'titel': 'LIC - inl opvoeren status en aktie SAN SAN', 'type': 'Handleidingen en instructies', 'link': 'https://connectpeople.belastingdienst.nl/files/form/anonymous/api/library/1fa8a980-ab6d-4c9a-a059-da1fea2c3dbf/document/119faf3b-f356-425f-b419-eb8f8e6f9fe2/media/4918%20LIC%20-%20inl%20opvoeren%20status%20en%20aktie%20SAN%20SAN.pdf'}, {'titel': 'LIC - inl opvoeren status en aktie SAN BVS', 'type': 'Handleidingen en instructies', 'link': 'https://connectpeople.belastingdienst.nl/files/form/anonymous/api/library/1fa8a980-ab6d-4c9a-a059-da1fea2c3dbf/document/e3075f76-4adf-4193-ad2b-300c0be24a1b/media/4919%20LIC%20-%20inl%20opvoeren%20status%20en%20aktie%20SAN%20BVS90.pdf'}, {'titel': 'Kwijtschelding', 'type': 'Handleidingen en instructies', 'link': 'https://connectpeople.belastingdienst.nl/communities/service/html/communityview?communityUuid=7fc3fb95-e8b6-4b11-b9ac-54a39938974e#fullpageWidgetId=W994fbe343309_4aad_b926_e4407b2cf5f3&file=dd8794cb-5bb2-487b-bce9-5dc4943c4f1d'}, {'titel': 'Beoordelen Vermogensbestanddelen', 'type': 'Handleidingen en instructies', 'link': 'https://connectpeople.belastingdienst.nl/communities/service/html/communityview?communityUuid=7fc3fb95-e8b6-4b11-b9ac-54a39938974e#fullpageWidgetId=W994fbe343309_4aad_b926_e4407b2cf5f3&file=e624fc75-14c3-4af2-befb-f5b641f92c00'}, {'titel': 'GID', 'type': 'Applicaties', 'link': 'https://gid.belastingdienst.nl/gid/?wdeURL=&wdetoken=&apiversion=#'}, {'titel': 'Tekst en commentaar insolventierecht', 'type': 'Achtergrond', 'link': 'https://www.inview.nl/document/id3691111b07b7450db1852772c190eaa1/tekst-commentaar-insolventierecht-afwijzingsgronden-bij-faillissementswet-artikel-288-beslissing-op-verzoek?ctx=WKNL_CSL_569&tab=tekst'}, {'titel': 'Uitvoeringsregeling invorderingswet', 'type': 'Handleidingen en instructies', 'link': 'https://wetten.overheid.nl/BWBR0004766/2025-01-01'}, {'titel': 'Invorderingswet', 'type': 'Bronnen', 'link': 'https://wetten.overheid.nl/BWBR0004770/2025-01-01'}, {'titel': 'Leidraad Invordering', 'type': 'Handleidingen en instructies', 'link': 'https://wetten.overheid.nl/BWBR0024096/2025-07-01'}, {'titel': 'IIB (instructie invordering belastingdeurwaarders', 'type': 'Handleidingen en instructies', 'link': 'https://download.belastingdienst.nl/belastingdienst/docs/instructie_invordering_en_belastingdeurwaarders_ov0211z78fd.pdf'}, {'titel': 'Faillissementswet', 'type': 'Bronnen', 'link': 'https://wetten.overheid.nl/BWBR0001860/2025-01-01'}, {'titel': 'Memo vastlegging Inning', 'type': 'Handleidingen en instructies', 'link': 'https://connectpeople.belastin ...

# %% [markdown]
# ### Tags taaksjabloon

# %%
import json
from ask_delphi_api.import_digicoach import Import
import datetime

json_digicoach = json.loads(json_coaches[0])
tags= json_digicoach['tags']
pprint.pprint(tags)
# Out:
# [{'type': 'Directie', 'values': ['CAP']},
#  {'type': 'Keten', 'values': ['Inning en betalingsverkeer']}]

# %% [markdown]
# ### Testset samenstellen

# %%
tags = [
    {'type' : 'Directie', 'values' : ['CAP', 'CD Communicatie', 'CD C&F', "CD FJZ"]}, 
    {'type' : 'Keten', 'values' : ['Inning en betalingsverkeer','Aangifte']},
    {'type' : 'Middel', 'values' : ['Kindertoeslag']}
]

# %% [markdown]
# ### Tags toevoegen

# %%
# Topic waar we een tag aan gaan koppelen
topic_id = "c4ff7354-e97c-44be-aa83-ac21b1a267a2"
topic_version_id = import_service.topic.get_topicVersionId(topic_id)

# Project tags ophalen (eenmalig opvragen lijkt mij)
print("Project tags ophalen :")
project_tags = import_service.relation.get_project_tags(topic_id, topic_version_id)

print("Topic tags aanleggen :")
import_service.relation.add_tags_to_topic(topic_id, topic_version_id, tags, project_tags)
# Out:
# Project tags ophalen :
# Topic tags aanleggen :
# Directie
# CAP (Centrale Administratieve Processen), fe932c90-e383-48c6-a3a5-beaa41ebe3a3
# CD Communicatie, fe932c90-e383-48c6-a3a5-beaa41ebe3a3
# CD Control en Financiën, fe932c90-e383-48c6-a3a5-beaa41ebe3a3
# CD Fiscale en Juridische zaken, fe932c90-e383-48c6-a3a5-beaa41ebe3a3
# Keten
# Inning en betalingsverkeer, 81edcdae-337a-4c11-a275-8f2a85be1033
# Aangifte, 81edcdae-337a-4c11-a275-8f2a85be1033
# Middel
# Kindertoeslag, 06989a96-4754-4057-b529-4a25d0c8df4a
