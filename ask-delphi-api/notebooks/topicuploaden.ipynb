# %%
from ask_delphi_api.authentication import AskDelphiClient
client = AskDelphiClient()
client.authenticate()   # pakt automatisch portal code uit .env
# Out:
# AskDelphi Client loaded.
# Parsed tenant/project/acl from CMS URL
# Loaded cached tokens.
# ============================================================
# AUTHENTICATION STARTED
# ============================================================
# Trying cached tokens...
# Editing API token status: 200
# Editing API token acquired.
# SUCCESS using cached tokens!
# True

# %% [markdown]
# ### Let op:
# Onderstaande code werkt momenteel alleen voor zandbak 0

# %%
from ask_delphi_api.topictools import TopicTools
topics = TopicTools(client)

#topics.topic_upload("Nieuwe procespagina", "Digitale Coach Procespagina")
topics.topic_upload("Nieuwe stap", "Stap")
#topics.topic_upload("Nieuwe Taak", "Taak")
# Out:
# ============================================================
# REQUEST: GET https://edit.api.askdelphi.com/v1/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/contentdesign
# RESPONSE: 200 OK
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 5
#       2 topics = TopicTools(client)
#       4 #topics.topic_upload("Nieuwe procespagina", "Digitale Coach Procespagina")
# ----> 5 topics.topic_upload("Nieuwe stap", "Stap")
#       6 #topics.topic_upload("Nieuwe Taak", "Taak")
#
# File ~\Documents\git\cog-boa-digicoaches\ask-delphi-api\src\ask_delphi_api\topictools.py:18, in TopicTools.topic_upload(self, topicTitle, topicTypeName)
#      16 def topic_upload(self, topicTitle: str, topicTypeName: str):
#      17     #topicTypeId = TOPIC_TYPE_IDS.get(topicTypeName)
# ---> 18     topicTypeId = self.project.get_topic_type_id(topicTypeName)
#      19     print(topicTypeId)
#      21     if topicTypeId is None:
#
# File ~\Documents\git\cog-boa-digicoaches\ask-delphi-api\src\ask_delphi_api\project.py:72, in Project.get_topic_type_id(self, topicTypeName)
#      69 topicTypeId = topic_type_map.get(topicTypeName)
#      71 if topicTypeId is None:
# ---> 72     raise ValueError(
#      73         f"Unknown topic type: '{topicTypeName}'."
#      74         f"Available types: {list(topic_type_map.keys())}"
#      75     )
#      77 return topicTypeId
#
# ValueError: Unknown topic type: 'Stap'.Available types: ['Questionnaire', 'Image map', 'Profile details portlet', 'Expandable items', 'My profile', 'Tabbed portlet', 'Skill area', 'ConnectPeople', 'SharePoint', 'Gallery', 'Micropolling definition', 'Blob', 'Publication Reference', 'Pre-defined search', 'Uitgeverij extern', 'Homepage', 'Cornerstone', 'Flipcard Portlet', 'Concept', 'Btube Link', 'Task', 'Digitale Coach Procespagina', 'External URL', 'Intranet', 'Hierarchy', 'Rakoo', 'Moodle', 'Person', 'Action', 'Pagina Structuur Voorgedefinieerde Zoekopdracht', 'Collection', 'Video', 'Quick question', 'Menu', 'Image', 'Glossary item', 'Digitale Coach Homepagina', 'Simple topic', 'Sketchbook']
