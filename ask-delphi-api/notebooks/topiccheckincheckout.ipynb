# %%
from ask_delphi_api.authentication import AskDelphiClient
client = AskDelphiClient()
client.authenticate()

# %%
from ask_delphi_api.topictools import TopicTools
topics = TopicTools(client)

# vul hieronder het topicId in van het topic dat je wil uitchecken
topicId = "dac77c17-b83c-4012-8da1-4a0f156639bc"
topics.checkout(topicId)

# %%
# Vul hieronder het topicId in van het topic dat je wil inchecken
topicId = "dac77c17-b83c-4012-8da1-4a0f156639bc"
topics.checkin(topicId)
