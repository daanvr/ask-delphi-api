# %% [markdown]
# # API verbinding opzetten

# %%
from ask_delphi_api.client import AskDelphiClient

# # from ask_delphi_ import AskDelphiClient
client = AskDelphiClient()
client.authenticate()   # pakt automatisch portal code uit .env
client.test_call()
# Out:
# Parsed tenant/project/acl from CMS URL
# Loaded cached tokens.
# ...
# AUTHENTICATION STARTED
# ...
# Trying cached tokens...
# Editing API token status: 401
# Cached tokens failed: Failed to fetch editing API token:
#
# Exchanging portal code...
# Status: 404
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 # # from ask_delphi_ import AskDelphiClient
#       4 client = AskDelphiClient()
# ----> 5 client.authenticate()   # pakt automatisch portal code uit .env
#       6 client.test_call()
#
# File ~\Documents\git\ask-delphi-api\ask-delphi-api\src\ask_delphi_api\client.py:85, in AskDelphiClient.authenticate(self, portal_code)
#      82 print("Status:", response.status_code)
#      84 if not response.ok:
# ---> 85     raise Exception(f"Portal authentication failed:\n{response.text}")
#      87 data = response.json()
# ...
