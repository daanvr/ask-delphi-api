# %% [markdown]
# ### https://edit.api.askdelphi.com/swagger/index.html

# %%
import os
import dotenv
import uuid

dotenv.load_dotenv()

os.getenv("ASKDELPHI_PORTAL_CODE")
# Out:
# 'ABC123-XYZ789'

# %%
from askdelphi_client import AskDelphiClient

client = AskDelphiClient()

client.authenticate()
# Out:
# 2026-01-28 14:46:05 | INFO     | Initializing AskDelphiClient...
# 2026-01-28 14:46:05 | INFO     |   Parsed IDs from CMS URL
# 2026-01-28 14:46:05 | INFO     |   Tenant ID: 0be6d42b-c278-44e6-888e-ba122840d690
# 2026-01-28 14:46:05 | INFO     |   Project ID: 397296f6-20dd-45cd-8459-250db2725140
# 2026-01-28 14:46:05 | INFO     |   ACL Entry ID: 4ecd88f2-979b-4fb0-a95d-175d499bc375
# 2026-01-28 14:46:05 | INFO     |   Portal Code: ABC1...Z789
# 2026-01-28 14:46:05 | INFO     |   Portal Server: https://portal.askdelphi.com
# 2026-01-28 14:46:05 | INFO     |   API Server: https://edit.api.askdelphi.com
# 2026-01-28 14:46:05 | INFO     | Loaded cached tokens from .askdelphi_tokens.json
# 2026-01-28 14:46:05 | DEBUG    |   Publication URL: https://digitalecoach.askdelphi.com
# 2026-01-28 14:46:05 | INFO     | ============================================================
# 2026-01-28 14:46:05 | INFO     | AUTHENTICATION STARTED
# 2026-01-28 14:46:05 | INFO     | ============================================================
# 2026-01-28 14:46:05 | INFO     | Found cached tokens, trying to use them...
# 2026-01-28 14:46:05 | DEBUG    | Getting API token...
# 2026-01-28 14:46:05 | DEBUG    | API token expired or expiring soon, trying refresh...
# 2026-01-28 14:46:05 | DEBUG    | Refreshing tokens...
# 2026-01-28 14:46:05 | DEBUG    | ============================================================
# 2026-01-28 14:46:05 | DEBUG    | REQUEST: GET https://digitalecoach.askdelphi.com/api/token/refresh?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....xIVXrmjQMthMRKB-TmwHtWN4W1NNHcaeZidpliFBPuY&refreshToken=mi1Lsk4msgm40QtRNTLmTBqh6mVB3JC2l2DSXrRLUxI=
# 2026-01-28 14:46:05 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 14:46:05 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 14:46:05 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 13:46:05 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '1024', 'Connection': 'keep-alive', 'Access-Control-Expose-Headers': 'Request-Context', 'Cache-Control': 'private', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=99762e18ad891432b0e579f71a2040bd889a4bf21332d81e853060cf05a42d65;Path=/;HttpOnly;Secure;Domain=digitalecoach.askdelphi.com, ARRAffinitySameSite=99762e18ad891432b0e579f71a2040bd889a4bf21332d81e853060cf05a42d65;Path=/;HttpOnly;SameSite=None;Secure;Domain=digitalecoach.askdelphi.com', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000', 'X-UA-Compatible': 'IE=edge', 'Request-Context': 'appId=cid-v1:6afe03cc-6beb-4194-a480-9f9e73f13632', 'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'no-referrer-when-downgrade', 'Permissions-Policy': 'accelerometer=(self), camera=(self), geolocation=(self), gyroscope=(self), magnetometer=(self), microphone=(self), payment=(self), usb=(self)', 'X-Permitted-Cross-Domain-Policies': 'none', 'Expect-CT': 'max-age=86400, enforce', 'x-azure-ref': '20260128T134605Z-r198d8c96762m8p5hC1PAReg2c0000000hvg000000007zbr', 'X-Cache': 'CONFIG_NOCACHE', 'Accept-Ranges': 'bytes'}
# 2026-01-28 14:46:05 | DEBUG    | Body (JSON): {
#   "refresh": "mi1Lsk4msgm40QtRNTLmTBqh6mVB3JC2l2DSXrRLUxI=",
#   "token": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....fs-25FICYQ3rp-JhPhPoagswlXuYdUx7l31YBYZtdao"
# }
# 2026-01-28 14:46:05 | DEBUG    | ============================================================
# 2026-01-28 14:46:06 | DEBUG    | Tokens saved to .askdelphi_tokens.json
# 2026-01-28 14:46:06 | INFO     | Tokens refreshed successfully
# 2026-01-28 14:46:06 | DEBUG    | ============================================================
# 2026-01-28 14:46:06 | DEBUG    | REQUEST: GET https://digitalecoach.askdelphi.com/api/token/EditingApiToken
# 2026-01-28 14:46:06 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 14:46:06 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 14:46:06 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 13:46:06 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '1227', 'Connection': 'keep-alive', 'Access-Control-Expose-Headers': 'Request-Context', 'Cache-Control': 'private, s-maxage=0', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=99762e18ad891432b0e579f71a2040bd889a4bf21332d81e853060cf05a42d65;Path=/;HttpOnly;Secure;Domain=digitalecoach.askdelphi.com, ARRAffinitySameSite=99762e18ad891432b0e579f71a2040bd889a4bf21332d81e853060cf05a42d65;Path=/;HttpOnly;SameSite=None;Secure;Domain=digitalecoach.askdelphi.com', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000', 'X-UA-Compatible': 'IE=edge', 'Request-Context': 'appId=cid-v1:6afe03cc-6beb-4194-a480-9f9e73f13632', 'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'no-referrer-when-downgrade', 'Permissions-Policy': 'accelerometer=(self), camera=(self), geolocation=(self), gyroscope=(self), magnetometer=(self), microphone=(self), payment=(self), usb=(self)', 'X-Permitted-Cross-Domain-Policies': 'none', 'Expect-CT': 'max-age=86400, enforce', 'x-azure-ref': '20260128T134606Z-r198d8c96767xmsthC1PARzy100000000kr000000000e0tz', 'X-Cache': 'CONFIG_NOCACHE', 'Accept-Ranges': 'bytes'}
# 2026-01-28 14:46:06 | DEBUG    | Body (JSON): "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....rMIDAxKg-y7QPfuVnVe2xcsC05f3enYs3I_YFmxWYm0"
# 2026-01-28 14:46:06 | DEBUG    | ============================================================
# 2026-01-28 14:46:06 | INFO     |   Received editing API token: eyJhbGciOiJIUzI1NiIsInR5cCI6Ik...
# 2026-01-28 14:46:06 | DEBUG    |   Token expires at: 2026-01-28 15:46:06
# 2026-01-28 14:46:06 | INFO     | SUCCESS: Authenticated using cached tokens
# True

# %% [markdown]
# ===== Get content design (topic types)

# %%
try:
    design = client.get_content_design()

    topic_types = design.get("topicTypes", [])
    print(f"Found {len(topic_types)} topic types:\n")

    for i, tt in enumerate(topic_types[:100]):  # Show first 100
        print(f"  {i+1}. {tt.get('title', 'Unknown')}")
        print(f"     ID: {tt.get('key', 'N/A')}")
        print(f"     Namespace: {tt.get('namespace', 'N/A')}")
        print()

    if len(topic_types) > 100:
        print(f"  ... and {len(topic_types) - 100} more")

except Exception as e:
    print(f"FAILED: {e}")
# Out:
# 2026-01-28 14:46:09 | INFO     | Getting content design...
# 2026-01-28 14:46:09 | DEBUG    | Getting API token...
# 2026-01-28 14:46:09 | DEBUG    | Using cached API token (still valid)
# 2026-01-28 14:46:09 | DEBUG    | ============================================================
# 2026-01-28 14:46:09 | DEBUG    | REQUEST: GET https://edit.api.askdelphi.com/v1/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/contentdesign
# 2026-01-28 14:46:09 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 14:46:09 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 14:46:09 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 13:46:09 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net, ARRAffinitySameSite=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;SameSite=None;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net', 'Vary': 'Accept-Encoding', 'Request-Context': 'appId=cid-v1:2382112b-f772-4837-9e13-979f2d67c6fc', 'X-Powered-By': 'ASP.NET', 'x-azure-ref': '20260128T134609Z-r198d8c9676shzbhhC1PARd95w0000000k1g000000002m1z', 'X-Cache': 'CONFIG_NOCACHE'}
# 2026-01-28 14:46:09 | DEBUG    | Body (JSON): {
#   "success": true,
#   "errorCode": null,
#   "errorMessage": null,
#   "response": {
#     "key": "00000000-0000-0000-0000-000000000000",
#     "title": null,
#     "pyramidLevels": [
#       {
#         "title": "Action",
#         "key": "16411853-9399-4d4f-afb4-081942d386f6",
#         "displayName": "Stap",
#         "isDeleted": false,
#         "sequenceNumber": 0,
#         "defaultRendering": null
#       },
#       {
#         "title": "Learning",
#         "key": "96e6c60c-99cd-4c3e-9fd0-0dfc655ed8bd",
#         "displayName": "Sjablonen en Tools",
#         "isDeleted": false,
#         "sequenceNumber": 0,
#         "defaultRendering": null
#       },
#       {
#         "title": "Supporting role",
#         "key": "ed71199e-3049-409c-bb7c-1000657c9f35",
#         "displayName": "Supporting role",
#         "isDeleted": false,
#         "sequenceNumber": 0,
#         "defaultRendering": null
#       },
#       {
#         "title": "People",
#         "key": "e7f52c78-59b0-4edc-8036-15fa178b61d1",
#         "displayName": "Experts",
#         "isDeleted": false,
#         "sequenceNumber": 0,
#         "defaultRendering": null
#       },
#       {
#         "title": "Miscellaneous",
#         "key": "56475328-414a-430a-b4ce-47c27623947b",
#         "displayName": "Handleidingen en Instructies",
#         "isDeleted": false,
#         "sequenceNumber": 0,
#         "defaultRendering": null
#       },
#       {
#         "title": "Systemen",
#         "key": "519e0c80-785b-43b4-ba29-55313d5feae2",
#         "displayName": "Applicaties",
#         "isDeleted": false,
#         "sequenceNumber": 0,
#         "defaultRendering": null
#       },
#       {
#         "title": "Concept",
#         "key": "92172d0f-3afa-42f4-8858-57e81de2a200",
#         "displayName": "Ondersteunende kennis",
#         "isDeleted": false,
#         "sequenceNumber": 0,
#         "defaultRendering": null
#       },
#       {
#         "title": "Video's",
#         "key": "a214d501-486c-4e5f-8265-5a95bcfa88a8",
#         "displayName": "Video's",
#         "isDeleted": false,
#         "sequenceNumber": 0,
#
# 2026-01-28 14:46:09 | DEBUG    | ============================================================
# Found 39 topic types:
#
#   1. Questionnaire
#      ID: c1225506-63e2-4785-9e51-06a587d54a9c
#      Namespace: http://tempuri.org/imola-questionnaire
#
#   2. Image map
#      ID: dac8be46-310c-4000-a6ae-0b598ea55ae7
#      Namespace: http://tempuri.org/doppio-imagemap
#
#   3. Profile details portlet
#      ID: 67466b32-3842-44bf-9f68-0cedb5efa199
#      Namespace: http://tempuri.org/imola-profile-details-portlet
#
#   4. Expandable items
#      ID: 791702ff-4dc9-443d-bba8-0f28a3639f3b
#      Namespace: http://tempuri.org/imola-expandable-content
#
#   5. My profile
#      ID: d89f511e-b8c8-437c-ba9d-116d3ed6b146
#      Namespace: http://tempuri.org/imola-profile
#
#   6. Tabbed portlet
#      ID: d2d2da24-7d44-46e1-808a-11fe621347c3
#      Namespace: http://tempuri.org/imola-tabbed-portlet
#
#   7. Skill area
#      ID: be94f430-64b1-4000-a2a5-1a5a151426bf
#      Namespace: http://tempuri.org/imola-skill-area
#
#   8. ConnectPeople
#      ID: e5a7b60c-5b45-45b5-8c00-2bfaa4b068b4
#      Namespace: http://tempuri.org/doppio-external
#
#   9. SharePoint
#      ID: 8959002a-806f-4c7d-a47d-2e36c66d4d6c
#      Namespace: http://tempuri.org/doppio-external
#
#   10. Gallery
#      ID: 8f96ac4b-5bf7-448e-9d14-3308c201aa96
#      Namespace: http://tempuri.org/doppio-gallery
#
#   11. Micropolling definition
#      ID: 6c881829-a743-4522-b4a3-33dcedc2d6d5
#      Namespace: http://tempuri.org/imola-micro-polling-definition
#
#   12. Blob
#      ID: aece62fc-2ed5-48c3-8508-36c28d1e02b1
#      Namespace: http://tempuri.org/doppio-blob
#
#   13. Publication Reference
#      ID: 20dc729a-beb0-4d01-b020-3cd8d9383c3c
#      Namespace: http://tempuri.org/imola-publication-reference
#
#   14. Pre-defined search
#      ID: 72aaefbb-1c09-4f89-8830-54194b03523b
#      Namespace: http://tempuri.org/imola-pre-defined-search
#
#   15. Uitgeverij extern
#      ID: ba75b3b4-d3cb-4e89-a899-62c627854cb8
#      Namespace: http://tempuri.org/doppio-external
#
#   16. Homepage
#      ID: 38a23602-65f5-4d32-96c5-770280116f8e
#      Namespace: http://tempuri.org/imola-homepage
#
#   17. Cornerstone
#      ID: 5d9a3a07-0ab3-4cb1-9158-78843c0f08a9
#      Namespace: http://tempuri.org/doppio-external
#
#   18. Flipcard Portlet
#      ID: 4f5e8ca7-b40a-42bc-beb6-7d419b94f189
#      Namespace: http://tempuri.org/imola-flipcard-portlet
#
#   19. Concept
#      ID: ae4dd3b4-3d52-4144-87fd-804c614051d4
#      Namespace: http://tempuri.org/imola-concept
#
#   20. Btube Link
#      ID: bbd6f557-2246-472f-aa2e-830745a3f462
#      Namespace: http://tempuri.org/doppio-external
#
#   21. Task
#      ID: 6aba8437-c8df-42d2-a868-840847c124ca
#      Namespace: http://tempuri.org/imola-task
#
#   22. Digitale Coach Procespagina
#      ID: 7d332fbb-44f5-469f-b570-874e701e526b
#      Namespace: http://tempuri.org/imola-skill-area
#
#   23. External URL
#      ID: 64707088-30a9-45f3-a4cf-8d60e43ac965
#      Namespace: http://tempuri.org/doppio-external
#
#   24. Intranet
#      ID: ece342d0-593a-4c22-828f-8db6934ecec3
#      Namespace: http://tempuri.org/doppio-external
#
#   25. Hierarchy
#      ID: 776892da-9f31-4856-8f3d-9196fceb3755
#      Namespace: http://tempuri.org/doppio-hierarchy
#
#   26. Rakoo
#      ID: 7c9e88e5-e99a-4f04-8ebc-9c1cf7f19931
#      Namespace: http://tempuri.org/doppio-external
#
#   27. Moodle
#      ID: 401b40ee-da71-4bdb-abf1-aede6542f0b0
#      Namespace: http://tempuri.org/doppio-external
#
#   28. Person
#      ID: 3af3bf81-6a7e-4938-860b-afe2c97234df
#      Namespace: http://tempuri.org/imola-person
#
#   29. Action
#      ID: c568af9a-6c89-45cf-a580-bc94e1c62ae3
#      Namespace: http://tempuri.org/imola-action
#
#   30. Pagina Structuur Voorgedefinieerde Zoekopdracht
#      ID: bbce37d3-2023-4d93-80ca-bd3a6722143d
#      Namespace: http://tempuri.org/imola-pre-defined-search
#
#   31. Collection
#      ID: ee51338e-4057-4beb-9223-bf40d1a43336
#      Namespace: http://tempuri.org/imola-collection
#
#   32. Video
#      ID: b740c526-a677-4663-8704-c1db9767f9a5
#      Namespace: http://tempuri.org/imola-video
#
#   33. Quick question
#      ID: eb25fa77-2bdc-42a2-8df0-cf1dbd06b104
#      Namespace: http://tempuri.org/imola-quick-question
#
#   34. Menu
#      ID: 22cd8efa-bd6c-4439-86fd-d1c6cb20ea21
#      Namespace: http://tempuri.org/imola-menu
#
#   35. Image
#      ID: 4a50fb1c-8645-4bb7-b5c9-d74a98181d73
#      Namespace: http://tempuri.org/doppio-image
#
#   36. Glossary item
#      ID: 4ffc6ab8-ae5a-42f0-bc79-e37e7b70fce3
#      Namespace: http://tempuri.org/imola-glossary-item
#
#   37. Digitale Coach Homepagina
#      ID: 2adc7b08-7c24-43db-9527-e79838b59551
#      Namespace: http://tempuri.org/imola-homepage
#
#   38. Simple topic
#      ID: e647b854-7f0c-4268-9946-f49935795bc7
#      Namespace: http://tempuri.org/imola-simple-topic
#
#   39. Sketchbook
#      ID: 20d314fc-f8ca-4f89-ab39-f50fca17ceb8
#      Namespace: http://tempuri.org/imola-sketchbook

# %% [markdown]
# ===== Creates a new task topic with the specified title and type in the given project and tenant.
#
# - <param name="context">API context containing authentication, tenant, project, and ACL information.</param>
# - <param name="topicTitle">The title of the topic to create.</param>
# - <param name="topicTypeId">The unique identifier of the topic type.</param>
# - <returns>The identifier for the newly created topic version.</returns>

# %%
# Create a task Topic
topic_id = str(uuid.uuid4())

result = client._request(
    "POST",
    "v4/tenant/{tenantId}/project/{projectId}/acl/{aclEntryId}/topic",
    json_data={
        "topicId": topic_id,
        "topicTitle": "API Test Topic f7cf7f58",
        "topicTypeId": "6aba8437-c8df-42d2-a868-840847c124ca",
         "copyParentTags": False
        }
)

topicId = result.get('topicId')
topicVersionKey = result.get('topicVersionKey')

print("Task topic created!")
print(f"  - Topic ID: {topicId}")
print(f"  - Version ID: {topicVersionKey}")
# Out:
# 2026-01-28 14:46:12 | DEBUG    | Getting API token...
# 2026-01-28 14:46:12 | DEBUG    | Using cached API token (still valid)
# 2026-01-28 14:46:12 | DEBUG    | ============================================================
# 2026-01-28 14:46:12 | DEBUG    | REQUEST: POST https://edit.api.askdelphi.com/v4/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic
# 2026-01-28 14:46:12 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 14:46:12 | DEBUG    | Body: {
#   "topicId": "c122273e-e933-48c5-b8a8-ed46d65a418a",
#   "topicTitle": "API Test Topic f7cf7f58",
#   "topicTypeId": "6aba8437-c8df-42d2-a868-840847c124ca",
#   "copyParentTags": false
# }
# 2026-01-28 14:46:12 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 14:46:12 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 13:46:12 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=ee61d7147620e118589b6fb149616398bb7a6c057f7f0b4263de84a2a21c0b3c;Path=/;HttpOnly;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net, ARRAffinitySameSite=ee61d7147620e118589b6fb149616398bb7a6c057f7f0b4263de84a2a21c0b3c;Path=/;HttpOnly;SameSite=None;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net', 'Vary': 'Accept-Encoding', 'Request-Context': 'appId=cid-v1:2382112b-f772-4837-9e13-979f2d67c6fc', 'X-Powered-By': 'ASP.NET', 'x-azure-ref': '20260128T134612Z-r1f47c87566ljt8mhC1PAR930s0000001zng000000000g41', 'X-Cache': 'CONFIG_NOCACHE'}
# 2026-01-28 14:46:12 | DEBUG    | Body (JSON): {
#   "success": true,
#   "errorCode": null,
#   "errorMessage": null,
#   "response": {
#     "topicId": "c122273e-e933-48c5-b8a8-ed46d65a418a",
#     "topicVersionKey": "e27f12e9-f03f-430c-8ce8-ec3b89c0725d"
#   }
# }
# 2026-01-28 14:46:12 | DEBUG    | ============================================================
# Task topic created!
#   - Topic ID: c122273e-e933-48c5-b8a8-ed46d65a418a
#   - Version ID: e27f12e9-f03f-430c-8ce8-ec3b89c0725d

# %% [markdown]
# Adds a relation to topic. Creates a relation from one topic version to another, using the specified relation type.
#
# - <param name="context">API context containing authentication, tenant, project, and ACL information.</param>
# - <param name="sourceTopicId">The identifier of the source topic version.</param>
# - <param name="targetTopicId">The identifier of the target topic version.</param>
# - <param name="relationType">The type of relation to create between the topics.</param>

# %%
# Create a relation.
topic_id_1 = str(uuid.uuid4())
topic_id_2 = str(uuid.uuid4())
topic_type_id = "6aba8437-c8df-42d2-a868-840847c124ca"
relation_type_id = "3"

# Maak twee topics
result_1 = client._request(
    "POST",
    "v4/tenant/{tenantId}/project/{projectId}/acl/{aclEntryId}/topic",
    json_data={
        "topicId": topic_id_1,
        "topicTitle": "Test Topic 1",
        "topicTypeId": topic_type_id,
         "copyParentTags": False
        }
)

print("Task topic 1 created!")
print(f"  - Topic ID: {topicId}")
print(f"  - Version ID: {topicVersionKey}")

result_2 = client._request(
    "POST",
    "v4/tenant/{tenantId}/project/{projectId}/acl/{aclEntryId}/topic",
    json_data={
        "topicId": topic_id_2,
        "topicTitle": "Test Topic 2",
        "topicTypeId": topic_type_id,
         "copyParentTags": False
        }
)

print("Task topic 2 created!")
print(f"  - Topic ID: {topicId}")
print(f"  - Version ID: {topicVersionKey}")

# Checkout eerste topic voor bewerking.
endpoint = f"/v1/tenant/{{tenantId}}/project/{{projectId}}/acl/{{aclEntryId}}/topic/{topic_id_1}/workflowstate"
result = client._request("POST", endpoint,
                json_data={
                    "action": 1
                })
topicVersionId = result["topicVersionId"]

print(f"  - TopicVersion ID: {topicVersionId}")

# Voeg een relatie toe van dit topic naar andere topics.
# print(f"✅ ADD Relation: Relatie toegevoegd van {topic_id_1} naar {topic_id_2}")

# Voeg een relatie toe van dit topic naar andere topics.
endpoint = f"v2/tenant/{{tenantId}}/project/{{projectId}}/acl/{{aclEntryId}}/topic/{topic_id_1}/topicVersion/{topicVersionId}/relation"
result = client._request(
    "POST", 
    endpoint,
    json_data={
        "relationTypeId": [],
        "sourceTopicId": topic_id_1,
        "targetTopicIds": [topic_id_2]
    })
# Out:
# 2026-01-28 15:43:43 | DEBUG    | Getting API token...
# 2026-01-28 15:43:43 | DEBUG    | Using cached API token (still valid)
# 2026-01-28 15:43:43 | DEBUG    | ============================================================
# 2026-01-28 15:43:43 | DEBUG    | REQUEST: POST https://edit.api.askdelphi.com/v4/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic
# 2026-01-28 15:43:43 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 15:43:43 | DEBUG    | Body: {
#   "topicId": "a59368ea-1ab2-4286-9397-af59739e0c42",
#   "topicTitle": "Test Topic 1",
#   "topicTypeId": "6aba8437-c8df-42d2-a868-840847c124ca",
#   "copyParentTags": false
# }
# 2026-01-28 15:43:43 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 15:43:43 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 14:43:43 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=ee61d7147620e118589b6fb149616398bb7a6c057f7f0b4263de84a2a21c0b3c;Path=/;HttpOnly;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net, ARRAffinitySameSite=ee61d7147620e118589b6fb149616398bb7a6c057f7f0b4263de84a2a21c0b3c;Path=/;HttpOnly;SameSite=None;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net', 'Vary': 'Accept-Encoding', 'Request-Context': 'appId=cid-v1:2382112b-f772-4837-9e13-979f2d67c6fc', 'X-Powered-By': 'ASP.NET', 'x-azure-ref': '20260128T144343Z-r198d8c96767qrvnhC1PARg1780000000hng00000000a2g5', 'X-Cache': 'CONFIG_NOCACHE'}
# 2026-01-28 15:43:43 | DEBUG    | Body (JSON): {
#   "success": true,
#   "errorCode": null,
#   "errorMessage": null,
#   "response": {
#     "topicId": "a59368ea-1ab2-4286-9397-af59739e0c42",
#     "topicVersionKey": "433ce077-dc84-4676-9cb7-dc27d4d96cd0"
#   }
# }
# 2026-01-28 15:43:43 | DEBUG    | ============================================================
# 2026-01-28 15:43:43 | DEBUG    | Getting API token...
# 2026-01-28 15:43:43 | DEBUG    | Using cached API token (still valid)
# 2026-01-28 15:43:43 | DEBUG    | ============================================================
# 2026-01-28 15:43:43 | DEBUG    | REQUEST: POST https://edit.api.askdelphi.com/v4/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic
# 2026-01-28 15:43:43 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 15:43:43 | DEBUG    | Body: {
#   "topicId": "556126a6-79c1-42c1-a94b-00462eb5f3d9",
#   "topicTitle": "Test Topic 2",
#   "topicTypeId": "6aba8437-c8df-42d2-a868-840847c124ca",
#   "copyParentTags": false
# }
# Task topic 1 created!
#   - Topic ID: c122273e-e933-48c5-b8a8-ed46d65a418a
#   - Version ID: e27f12e9-f03f-430c-8ce8-ec3b89c0725d
# 2026-01-28 15:43:44 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 15:43:44 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 14:43:44 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net, ARRAffinitySameSite=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;SameSite=None;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net', 'Vary': 'Accept-Encoding', 'Request-Context': 'appId=cid-v1:2382112b-f772-4837-9e13-979f2d67c6fc', 'X-Powered-By': 'ASP.NET', 'x-azure-ref': '20260128T144343Z-r1f47c87566bt2kchC1PARynv80000001x7g000000008hq8', 'X-Cache': 'CONFIG_NOCACHE'}
# 2026-01-28 15:43:44 | DEBUG    | Body (JSON): {
#   "success": true,
#   "errorCode": null,
#   "errorMessage": null,
#   "response": {
#     "topicId": "556126a6-79c1-42c1-a94b-00462eb5f3d9",
#     "topicVersionKey": "254707d6-216c-4908-918d-b8b8656a1ec2"
#   }
# }
# 2026-01-28 15:43:44 | DEBUG    | ============================================================
# 2026-01-28 15:43:44 | DEBUG    | Getting API token...
# 2026-01-28 15:43:44 | DEBUG    | Using cached API token (still valid)
# 2026-01-28 15:43:44 | DEBUG    | ============================================================
# 2026-01-28 15:43:44 | DEBUG    | REQUEST: POST https://edit.api.askdelphi.com//v1/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic/a59368ea-1ab2-4286-9397-af59739e0c42/workflowstate
# 2026-01-28 15:43:44 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 15:43:44 | DEBUG    | Body: {
#   "action": 1
# }
# Task topic 2 created!
#   - Topic ID: c122273e-e933-48c5-b8a8-ed46d65a418a
#   - Version ID: e27f12e9-f03f-430c-8ce8-ec3b89c0725d
# 2026-01-28 15:43:45 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 15:43:45 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 14:43:45 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net, ARRAffinitySameSite=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;SameSite=None;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net', 'Vary': 'Accept-Encoding', 'Request-Context': 'appId=cid-v1:2382112b-f772-4837-9e13-979f2d67c6fc', 'X-Powered-By': 'ASP.NET', 'x-azure-ref': '20260128T144344Z-r198d8c9676s7g42hC1PARu0r80000000hrg0000000040zd', 'X-Cache': 'CONFIG_NOCACHE'}
# 2026-01-28 15:43:45 | DEBUG    | Body (JSON): {
#   "success": true,
#   "errorCode": null,
#   "errorMessage": null,
#   "response": {
#     "status": true,
#     "topicVersionId": "da78b74a-a74e-4bc1-90d5-7f7b081b11df"
#   }
# }
# 2026-01-28 15:43:45 | DEBUG    | ============================================================
# 2026-01-28 15:43:45 | DEBUG    | Getting API token...
# 2026-01-28 15:43:45 | DEBUG    | Using cached API token (still valid)
# 2026-01-28 15:43:45 | DEBUG    | ============================================================
# 2026-01-28 15:43:45 | DEBUG    | REQUEST: POST https://edit.api.askdelphi.com/v2/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic/a59368ea-1ab2-4286-9397-af59739e0c42/topicVersion/da78b74a-a74e-4bc1-90d5-7f7b081b11df/relation
# 2026-01-28 15:43:45 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 15:43:45 | DEBUG    | Body: {
#   "sourceTopicId": "a59368ea-1ab2-4286-9397-af59739e0c42",
#   "targetTopicIds": [
#     "556126a6-79c1-42c1-a94b-00462eb5f3d9"
#   ]
# }
#   - TopicVersion ID: da78b74a-a74e-4bc1-90d5-7f7b081b11df
# 2026-01-28 15:43:45 | DEBUG    | RESPONSE: 400 Bad Request
# 2026-01-28 15:43:45 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 14:43:45 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'ARRAffinity=ee61d7147620e118589b6fb149616398bb7a6c057f7f0b4263de84a2a21c0b3c;Path=/;HttpOnly;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net, ARRAffinitySameSite=ee61d7147620e118589b6fb149616398bb7a6c057f7f0b4263de84a2a21c0b3c;Path=/;HttpOnly;SameSite=None;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net', 'Request-Context': 'appId=cid-v1:2382112b-f772-4837-9e13-979f2d67c6fc', 'X-Powered-By': 'ASP.NET', 'x-azure-ref': '20260128T144345Z-r1f47c87566tkbxshC1PARs6280000001ym000000000fsdk', 'X-Cache': 'CONFIG_NOCACHE'}
# 2026-01-28 15:43:45 | DEBUG    | Body (JSON): {
#   "success": false,
#   "errorCode": "ERR20003",
#   "errorMessage": "Failed to get topic type relation by id: 00000000-0000-0000-0000-000000000000 from content design",
#   "response": null
# }
# 2026-01-28 15:43:45 | DEBUG    | ============================================================
# 2026-01-28 15:43:45 | ERROR    | API POST v2/tenant/{tenantId}/project/{projectId}/acl/{aclEntryId}/topic/a59368ea-1ab2-4286-9397-af59739e0c42/topicVersion/da78b74a-a74e-4bc1-90d5-7f7b081b11df/relation failed!
#
#   Status Code: 400 Bad Request
#   URL: https://edit.api.askdelphi.com/v2/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic/a59368ea-1ab2-4286-9397-af59739e0c42/topicVersion/da78b74a-a74e-4bc1-90d5-7f7b081b11df/relation
#   Content-Type: application/json; charset=utf-8
#   Response (JSON): {
#     "success": false,
#     "errorCode": "ERR20003",
#     "errorMessage": "Failed to get topic type relation by id: 00000000-0000-0000-0000-000000000000 from content design",
#     "response": null
# }
#
# Troubleshooting:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[51], line 53
#      48 # Voeg een relatie toe van dit topic naar andere topics.
#      49 # print(f"✅ ADD Relation: Relatie toegevoegd van {topic_id_1} naar {topic_id_2}")
#      50
#      51 # Voeg een relatie toe van dit topic naar andere topics.
#      52 endpoint = f"v2/tenant/{{tenantId}}/project/{{projectId}}/acl/{{aclEntryId}}/topic/{topic_id_1}/topicVersion/{topicVersionId}/relation"
# ---> 53 result = client._request(
#      54     "POST",
#      55     endpoint,
#      56     json_data={
#      57         "sourceTopicId": topic_id_1,
#      58         "targetTopicIds": [topic_id_2]
#      59     })
#
# File ~/projects/ask-delphi-api/askdelphi_client.py:664, in AskDelphiClient._request(self, method, endpoint, json_data, params)
#     662     error_msg = self._format_error_response(response, f"API {method} {endpoint}")
#     663     logger.error(error_msg)
# --> 664     raise Exception(error_msg)
#     666 data = response.json()
#     668 # Handle wrapped response
#
# Exception: API POST v2/tenant/{tenantId}/project/{projectId}/acl/{aclEntryId}/topic/a59368ea-1ab2-4286-9397-af59739e0c42/topicVersion/da78b74a-a74e-4bc1-90d5-7f7b081b11df/relation failed!
#
#   Status Code: 400 Bad Request
#   URL: https://edit.api.askdelphi.com/v2/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic/a59368ea-1ab2-4286-9397-af59739e0c42/topicVersion/da78b74a-a74e-4bc1-90d5-7f7b081b11df/relation
#   Content-Type: application/json; charset=utf-8
#   Response (JSON): {
#     "success": false,
#     "errorCode": "ERR20003",
#     "errorMessage": "Failed to get topic type relation by id: 00000000-0000-0000-0000-000000000000 from content design",
#     "response": null
# }
#
# Troubleshooting:

# %%
# Delete task Topic
endpoint = f"/v1/tenant/{{tenantId}}/project/{{projectId}}/acl/{{aclEntryId}}/topic/{topicId}/workflowstate"
result = client._request("POST", endpoint,
                json_data={
                    "action": 1
                })
topicVersionId = result["topicVersionId"]
# Out:
# 2026-01-28 13:36:41 | DEBUG    | Getting API token...
# 2026-01-28 13:36:41 | DEBUG    | Using cached API token (still valid)
# 2026-01-28 13:36:41 | DEBUG    | ============================================================
# 2026-01-28 13:36:41 | DEBUG    | REQUEST: POST https://edit.api.askdelphi.com//v1/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic/7925f17a-4364-4214-a396-708904721eca/workflowstate
# 2026-01-28 13:36:41 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 13:36:41 | DEBUG    | Body: {
#   "action": 1
# }
# 2026-01-28 13:36:43 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 13:36:43 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 12:36:43 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net, ARRAffinitySameSite=b82e99a67c67934cccb8b149fcc4f13b341aa056d5e3ae7bf711611e78ecb2a8;Path=/;HttpOnly;SameSite=None;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net', 'Vary': 'Accept-Encoding', 'Request-Context': 'appId=cid-v1:2382112b-f772-4837-9e13-979f2d67c6fc', 'X-Powered-By': 'ASP.NET', 'x-azure-ref': '20260128T123642Z-165d6fc6f854cf7mhC1JNBfu140000000m0g00000000dgv1', 'X-Cache': 'CONFIG_NOCACHE'}
# 2026-01-28 13:36:43 | DEBUG    | Body (JSON): {
#   "success": true,
#   "errorCode": null,
#   "errorMessage": null,
#   "response": {
#     "status": true,
#     "topicVersionId": "9cb6f01d-cb37-405b-bb91-7b168021df15"
#   }
# }
# 2026-01-28 13:36:43 | DEBUG    | ============================================================

# %%
endpoint = f"v3/tenant/{{tenantId}}/project/{{projectId}}/acl/{{aclEntryId}}/topic/{topicId}/topicVersion/{topicVersionId}"

client._request("DELETE", endpoint,
    json_data={
        "workflowActions": {}
    }
)
# Out:
# 2026-01-28 13:36:44 | DEBUG    | Getting API token...
# 2026-01-28 13:36:44 | DEBUG    | Using cached API token (still valid)
# 2026-01-28 13:36:44 | DEBUG    | ============================================================
# 2026-01-28 13:36:44 | DEBUG    | REQUEST: DELETE https://edit.api.askdelphi.com/v3/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic/7925f17a-4364-4214-a396-708904721eca/topicVersion/9cb6f01d-cb37-405b-bb91-7b168021df15
# 2026-01-28 13:36:44 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-28 13:36:44 | DEBUG    | Body: {
#   "workflowActions": {}
# }
# 2026-01-28 13:36:46 | DEBUG    | RESPONSE: 200 OK
# 2026-01-28 13:36:46 | DEBUG    | Headers: {'Date': 'Wed, 28 Jan 2026 12:36:46 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ARRAffinity=ee61d7147620e118589b6fb149616398bb7a6c057f7f0b4263de84a2a21c0b3c;Path=/;HttpOnly;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net, ARRAffinitySameSite=ee61d7147620e118589b6fb149616398bb7a6c057f7f0b4263de84a2a21c0b3c;Path=/;HttpOnly;SameSite=None;Secure;Domain=as-askdelphi-prod-edit-api-001.azurewebsites.net', 'Vary': 'Accept-Encoding', 'Request-Context': 'appId=cid-v1:2382112b-f772-4837-9e13-979f2d67c6fc', 'X-Powered-By': 'ASP.NET', 'x-azure-ref': '20260128T123645Z-165d6fc6f85rh9fvhC1JNBbyd80000000m600000000016cx', 'X-Cache': 'CONFIG_NOCACHE'}
# 2026-01-28 13:36:46 | DEBUG    | Body (JSON): {
#   "success": true,
#   "errorCode": null,
#   "errorMessage": null,
#   "response": {}
# }
# 2026-01-28 13:36:46 | DEBUG    | ============================================================
# {}
