# %%
import os
import dotenv

dotenv.load_dotenv()

os.getenv("ASKDELPHI_PORTAL_CODE")
# Out:
# 'QH4206-5N03C1'

# %%
from askdelphi_client import AskDelphiClient

client = AskDelphiClient()

client.authenticate()
# Out:
# 2026-01-22 15:23:50 | INFO     | Initializing AskDelphiClient...
# 2026-01-22 15:23:50 | INFO     |   Parsed IDs from CMS URL
# 2026-01-22 15:23:50 | INFO     |   Tenant ID: 0be6d42b-c278-44e6-888e-ba122840d690
# 2026-01-22 15:23:50 | INFO     |   Project ID: 397296f6-20dd-45cd-8459-250db2725140
# 2026-01-22 15:23:50 | INFO     |   ACL Entry ID: 4ecd88f2-979b-4fb0-a95d-175d499bc375
# 2026-01-22 15:23:50 | INFO     |   Portal Code: QH42...03C1
# 2026-01-22 15:23:50 | INFO     |   Portal Server: https://portal.askdelphi.com
# 2026-01-22 15:23:50 | INFO     |   API Server: https://edit.api.askdelphi.com
# 2026-01-22 15:23:50 | INFO     | Loaded cached tokens from .askdelphi_tokens.json
# 2026-01-22 15:23:50 | DEBUG    |   Publication URL: https://digitalecoach.askdelphi.com
# 2026-01-22 15:23:50 | INFO     | ============================================================
# 2026-01-22 15:23:50 | INFO     | AUTHENTICATION STARTED
# ...

# %%
client._request(
    "GET",
    "/v1/tenant/{tenantId}/project/{projectId}/acl/{aclEntryId}/topic/ffa00f9e-2938-4ecd-863e-550190ae233b/version/history/list",
)
# Out:
# 2026-01-22 15:44:11 | DEBUG    | Getting API token...
# 2026-01-22 15:44:11 | DEBUG    | Using cached API token (still valid)
# 2026-01-22 15:44:11 | DEBUG    | ============================================================
# 2026-01-22 15:44:11 | DEBUG    | REQUEST: GET https://edit.api.askdelphi.com//v1/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic/ffa00f9e-2938-4ecd-863e-550190ae233b/version/history/list
# 2026-01-22 15:44:11 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-22 15:44:11 | DEBUG    | RESPONSE: 200 OK
# ...

# %%
client._request(
    "DELETE",
    "v3/tenant/{tenantId}/project/{projectId}/acl/{aclEntryId}/topic/ffa00f9e-2938-4ecd-863e-550190ae233b/topicVersion/8e2da002-2bc7-4776-a49e-4008685f0962",
    json_data={
        "workflowActions": {}
    }
)
# Out:
# 2026-01-22 15:44:34 | DEBUG    | Getting API token...
# 2026-01-22 15:44:34 | DEBUG    | Using cached API token (still valid)
# 2026-01-22 15:44:34 | DEBUG    | ============================================================
# 2026-01-22 15:44:34 | DEBUG    | REQUEST: DELETE https://edit.api.askdelphi.com/v3/tenant/0be6d42b-c278-44e6-888e-ba122840d690/project/397296f6-20dd-45cd-8459-250db2725140/acl/4ecd88f2-979b-4fb0-a95d-175d499bc375/topic/ffa00f9e-2938-4ecd-863e-550190ae233b/topicVersion/8e2da002-2bc7-4776-a49e-4008685f0962
# 2026-01-22 15:44:34 | DEBUG    | Headers: {
#   "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW...",
#   "Content-Type": "application/json",
#   "Accept": "application/json",
#   "User-Agent": "AskDelphi-Python-Client/1.0"
# }
# 2026-01-22 15:44:34 | DEBUG    | Body: {
#   "workflowActions": {}
# }
# 2026-01-22 15:44:35 | DEBUG    | RESPONSE: 400 Bad Request
# ...
